# %%
# Sample data structure for the table of values
data_table = {
    (14, 8): {'Torque': 138, 'Tension': 100},
    (14, 10): {'Torque': 150, 'Tension': 110},
    (14, 12): {'Torque': 162, 'Tension': 120},
    # Add more entries as needed
}

# Function to get user input for size and quality
def get_user_input():
    size = int(input("Enter Size of bolt (e.g., 14): "))
    quality = int(input("Choose Quality of bolt (8, 10, 12): "))
    return size, quality

# Function to choose between Torque or Tensioner
def choose_torque_or_tension():
    choice = input("Choose Torque or Tensioner: ").strip().lower()
    return choice

# Function to choose between hydraulic or rotary screwdriver
def choose_tool_type():
    tool_type = input("Choose Hydraulic or Rotary screwdriver: ").strip().lower()
    return tool_type

# Function to choose tool subtype
def choose_tool_subtype(tool_type):
    if tool_type == 'hydraulic':
        subtype = input("Choose Pneumatic, Electric, or Battery operated tool: ").strip().lower()
    elif tool_type == 'rotary':
        subtype = input("Choose Pneumatic, Electric, or Battery operated tool (different from hydraulic): ").strip().lower()
    else:
        print("Invalid tool type selected.")
        return None
    return subtype

# Main function to run the program
def main():
    size, quality = get_user_input()
    
    # Check if the combination exists in the data table
    if (size, quality) in data_table:
        print(f"Selected Size: {size}, Quality: {quality}")
        
        # Get Torque or Tensioner choice
        choice = choose_torque_or_tension()
        
        if choice in ['torque', 'tensioner']:
            value = data_table[(size, quality)][choice.capitalize()]
            print(f"The value corresponding to {choice} is: {value}")
            
            # Choose between hydraulic or rotary screwdriver
            tool_type = choose_tool_type()
            
            if tool_type in ['hydraulic', 'rotary']:
                subtype = choose_tool_subtype(tool_type)
                if subtype:
                    print(f"You have selected: {tool_type} -> {subtype}")
                else:
                    print("No valid subtype selected.")
            else:
                print("Invalid tool type selected.")
        else:
            print("Invalid choice for Torque or Tensioner.")
    else:
        print("Invalid Size or Quality combination.")

# Run the program
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 69
#      67 # Run the program
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# Cell In[1], line 38, in main()
#      37 def main():
# ---> 38     size, quality = get_user_input()
#      40     # Check if the combination exists in the data table
#      41     if (size, quality) in data_table:
#
# Cell In[1], line 11, in get_user_input()
#      10 def get_user_input():
# ---> 11     size = int(input("Enter Size of bolt (e.g., 14): "))
#      12     quality = int(input("Choose Quality of bolt (8, 10, 12): "))
#      13     return size, quality
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (1.24.3)

# %%
import pandas as pd

df = pd.read_csv('ML_Data.csv')
df
# Out:
#     Size Nut [mm]  Size Bolt [mm]  8.8 Torque  8.8 Tensioner  \
# 0              21              14         148             58
# 1              24              16         229             79
# 2              27              18         328             99
# 3              30              20         464            127
# 4              33              22         630            156
# 5              36              24         798            183
# 6              41              27        1180            240
# 7              46              30        1602            292
# 8              50              33        2167            364
# 9              55              36        2786            427
# 10             60              39        3606            513
# 11             65              42        4458            588
# 12             70              45        5566            687
# 13             75              48        6732            773
# 14             80              52        8648            926
# 15             85              56       10788           1069
# 16             90              60       13378           1247
# 17             95              64       16108           1412
# 18            100              68       19457           1616
# 19            105              72       24488           1834
# 20            110              76       27458           2066
# 21            115              80       32184           2311
# 22            130              90       46522           2985
# 23            145             100       64593           3745
#
#    8.8 Hydraulic Pneumatic Torque 8.8 Hydraulic Electrical Torque  \
# 0                         MX-EC 5                         MX-EC 5
# 1                         MX-EC 5                         MX-EC 5
# 2                         MX-EC 5                         MX-EC 5
# 3                         MX-EC 5                         MX-EC 5
# 4                        MX-EC 10                        MX-EC 10
# 5                        MX-EC 10                        MX-EC 10
# 6                        MX-EC 20                        MX-EC 20
# 7                        MX-EC 20                        MX-EC 20
# 8                        MX-EC 45                        MX-EC 45
# 9                        MX-EC 45                        MX-EC 45
# 10                       MX-EC 45                        MX-EC 45
# 11                       MX-EC 45                        MX-EC 45
# 12                       MX-EC 75                        MX-EC 75
# 13                       MX-EC 75                        MX-EC 75
# 14                       MX-EC 95                        MX-EC 95
# 15                      MX-EC 120                       MX-EC 120
# 16                      MX-EC 155                       MX-EC 155
# 17                      MX-EC 200                       MX-EC 200
# 18                      MX-EC 200                       MX-EC 200
# 19                      MX-EC 300                       MX-EC 300
# 20                      MX-EC 300                       MX-EC 300
# 21                            NaN                             NaN
# 22                            NaN                             NaN
# 23                            NaN                             NaN
#
#    8.8 Hydraulic Battery Torque 8.8 Rotatry Screwdriver Pneumatic Torque  \
# 0                       MX-EC 5                                   DP2-05
# 1                       MX-EC 5                                   DP2-05
# 2                       MX-EC 5                                   DP2-05
# 3                       MX-EC 5                                   DP2-05
# 4                      MX-EC 10                                   DP2-10
# 5                      MX-EC 10                                   DP2-10
# 6                      MX-EC 20                                   DP2-20
# 7                      MX-EC 20                                   DP2-20
# 8                      MX-EC 45                                   DP2-30
# 9                      MX-EC 45                                   DP2-30
# 10                     MX-EC 45                                   DP2-48
# 11                     MX-EC 45                                   DP2-48
# 12                     MX-EC 75                                   DP2-80
# 13                     MX-EC 75                                   DP2-80
# 14                     MX-EC 95                                      NaN
# 15                    MX-EC 120                                      NaN
# 16                    MX-EC 155                                      NaN
# 17                    MX-EC 200                                      NaN
# 18                    MX-EC 200                                      NaN
# 19                    MX-EC 300                                      NaN
# 20                    MX-EC 300                                      NaN
# 21                          NaN                                      NaN
# 22                          NaN                                      NaN
# 23                          NaN                                      NaN
#
#    8.8 Rotatry Screwdriver Electrical Torque  \
# 0                                     DE1-10
# 1                                     DE1-10
# 2                                     DE1-10
# 3                                     DE1-10
# 4                                     DE1-10
# 5                                     DE1-10
# 6                                     DE1-20
# 7                                     DE1-20
# 8                                     DE1-30
# 9                                     DE1-30
# 10                                    DE1-48
# 11                                    DE1-48
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
#
#    8.8 Rotatry Screwdriver Battery Torque  ...  12.9 Hydraulic Battery Torque  \
# 0                                  DA2-05  ...                        MX-EC 5
# 1                                  DA2-05  ...                        MX-EC 5
# 2                                  DA2-05  ...                       MX-EC 10
# 3                                  DA2-05  ...                       MX-EC 10
# 4                                  DA2-10  ...                       MX-EC 20
# 5                                  DA2-10  ...                       MX-EC 20
# 6                                  DA2-20  ...                       MX-EC 20
# 7                                  DA2-20  ...                       MX-EC 45
# 8                                  DA2-30  ...                       MX-EC 45
# 9                                  DA2-30  ...                       MX-EC 75
# 10                                 DA2-48  ...                       MX-EC 75
# 11                                 DA2-48  ...                       MX-EC 75
# 12                                 DA2-80  ...                       MX-EC 95
# 13                                 DA2-80  ...                      MX-EC 120
# 14                                    NaN  ...                      MX-EC 155
# 15                                    NaN  ...                      MX-EC 200
# 16                                    NaN  ...                      MX-EC 300
# 17                                    NaN  ...                      MX-EC 300
# 18                                    NaN  ...                            NaN
# 19                                    NaN  ...                            NaN
# 20                                    NaN  ...                            NaN
# 21                                    NaN  ...                            NaN
# 22                                    NaN  ...                            NaN
# 23                                    NaN  ...                            NaN
#
#     12.9 Rotatry Screwdriver Pneumatic Torque  \
# 0                                      DP2-05
# 1                                      DP2-05
# 2                                      DP2-10
# 3                                      DP2-10
# 4                                      DP2-20
# 5                                      DP2-20
# 6                                      DP2-20
# 7                                      DP2-30
# 8                                      DP2-48
# 9                                      DP2-48
# 10                                     DP2-80
# 11                                     DP2-80
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
#
#    12.9 Rotatry Screwdriver Electrical Torque  \
# 0                                      DE1-10
# 1                                      DE1-10
# 2                                      DE1-10
# 3                                      DE1-10
# 4                                      DE1-20
# 5                                      DE1-20
# 6                                      DE1-20
# 7                                      DE1-30
# 8                                      DE1-48
# 9                                      DE1-48
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
#
#    12.9 Rotatry Screwdriver Battery Torque 8.8 Pneumatic Tensioner  \
# 0                                   DA2-05                     NaN
# 1                                   DA2-05                     NaN
# 2                                   DA2-05                     NaN
# 3                                   DA2-10                  PSD 20
# 4                                   DA2-20                     NaN
# 5                                   DA2-20                  PSE 24
# 6                                   DA2-20                     NaN
# 7                                   DA2-30                  PSE 30
# 8                                   DA2-48                  PSD 33
# 9                                   DA2-48                  PSE 36
# 10                                  DA2-80                  PSE 39
# 11                                  DA2-80                  PSE 42
# 12                                     NaN                  PSE 45
# 13                                     NaN                  PSE 48
# 14                                     NaN                  PSE 52
# 15                                     NaN                  PSE 56
# 16                                     NaN                     NaN
# 17                                     NaN                  PSE 64
# 18                                     NaN                  PSD 72
# 19                                     NaN                     NaN
# 20                                     NaN                     NaN
# 21                                     NaN                  PSD 80
# 22                                     NaN                     NaN
# 23                                     NaN                     NaN
#
#    8.8 Electrical Tensioner 10.9 Pneumatic Tensioner  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                    PSD 20                   PSD 20
# 4                       NaN                      NaN
# 5                    PSE 24                   PSE 24
# 6                       NaN                      NaN
# 7                    PSE 30                   PSE 30
# 8                    PSD 33                   PSD 33
# 9                    PSE 36                   PSE 36
# 10                   PSE 39                   PSE 39
# 11                   PSE 42                   PSE 42
# 12                   PSE 45                   PSE 45
# 13                   PSE 48                   PSE 48
# 14                   PSE 52                   PSE 52
# 15                   PSE 56                   PSE 56
# 16                      NaN                      NaN
# 17                   PSE 64                   PSE 64
# 18                   PSD 72                   PSD 72
# 19                      NaN                      NaN
# 20                      NaN                      NaN
# 21                   PSD 80                   PSD 80
# 22                      NaN                      NaN
# 23                      NaN                      NaN
#
#    10.9 Electrical Tensioner  12.9 Pneumatic Tensioner  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                     PSD 20                    PSD 20
# 4                        NaN                       NaN
# 5                     PSE 24                    PSE 24
# 6                        NaN                       NaN
# 7                     PSE 30                    PSE 30
# 8                     PSD 33                    PSD 33
# 9                     PSE 36                    PSE 36
# 10                    PSE 39                    PSE 39
# 11                    PSE 42                    PSE 42
# 12                    PSE 45                    PSE 45
# 13                    PSE 48                    PSE 48
# 14                    PSE 52                    PSE 52
# 15                    PSE 56                    PSE 56
# 16                       NaN                       NaN
# 17                    PSE 64                    PSE 64
# 18                    PSD 72                    PSD 72
# 19                       NaN                       NaN
# 20                       NaN                       NaN
# 21                    PSD 80                    PSD 80
# 22                       NaN                       NaN
# 23                       NaN                       NaN
#
#     12.9 Electrical Tensioner
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                      PSD 20
# 4                         NaN
# 5                      PSE 24
# 6                         NaN
# 7                      PSE 30
# 8                      PSD 33
# 9                      PSE 36
# 10                     PSE 39
# 11                     PSE 42
# 12                     PSE 45
# 13                     PSE 48
# 14                     PSE 52
# 15                     PSE 56
# 16                        NaN
# 17                     PSE 64
# 18                     PSD 72
# 19                        NaN
# 20                        NaN
# 21                     PSD 80
# 22                        NaN
# 23                        NaN
#
# [24 rows x 32 columns]

# %%
import csv
import pandas as pd

# Function to load data from a CSV file into a dictionary
def load_data_from_csv(filename):
    data_table = {}
    with open(filename, mode='r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            size_bolt = int(row['Size Bolt [mm]'])
            quality = '8.8'  # Assuming we want to focus on quality levels
            # Store torque and tool types for each quality level
            data_table[(size_bolt, quality)] = {
                'Torque': row['8.8 Torque'],
                'Hydraulic Pneumatic Tool': row['8.8 Hydraulic Pneumatic Torque'],
                'Hydraulic Electrical Tool': row['8.8 Hydraulic Electrical Torque'],
                'Hydraulic Battery Tool': row['8.8 Hydraulic Battery Torque'],
                'Rotary Screwdriver Pneumatic Tool': row['8.8 Rotatry Screwdriver Pneumatic Torque'],
                'Rotary Screwdriver Electrical Tool': row['8.8 Rotatry Screwdriver Electrical Torque'],
                'Rotary Screwdriver Battery Tool': row['8.8 Rotatry Screwdriver Battery Torque']
            },
            {
                'Torque': row['10.9 Torque'],
                'Hydraulic Pneumatic Tool': row['10.9 Hydraulic Pneumatic Torque'],
                'Hydraulic Electrical Tool': row['10.9 Hydraulic Electrical Torque'],
                'Hydraulic Battery Tool': row['10.9 Hydraulic Battery Torque'],
                'Rotary Screwdriver Pneumatic Tool': row['10.9 Rotatry Screwdriver Pneumatic Torque'],
                'Rotary Screwdriver Electrical Tool': row['10.9 Rotatry Screwdriver Electrical Torque'],
                'Rotary Screwdriver Battery Tool': row['10.9 Rotatry Screwdriver Battery Torque']
            },
            {
                'Torque': row['12.9 Torque'],
                'Hydraulic Pneumatic Tool': row['12.9 Hydraulic Pneumatic Torque'],
                'Hydraulic Electrical Tool': row['12.9 Hydraulic Electrical Torque'],
                'Hydraulic Battery Tool': row['12.9 Hydraulic Battery Torque'],
                'Rotary Screwdriver Pneumatic Tool': row['12.9 Rotatry Screwdriver Pneumatic Torque'],
                'Rotary Screwdriver Electrical Tool': row['12.9 Rotatry Screwdriver Electrical Torque'],
                'Rotary Screwdriver Battery Tool': row['12.9 Rotatry Screwdriver Battery Torque']
            }
    return data_table

# Function to get user input for size and quality
def get_user_input():
    size = int(input("Enter Size of bolt (e.g., 14): "))
    quality = input("Choose Quality of bolt (e.g., 8.8, 10.9, 12.9): ")
    return size, quality

# Function to choose between torque or tensioner
def choose_torque_or_tension():
    choice = input("Choose Torque or Tensioner: ").strip().lower()
    return choice

# Function to choose between hydraulic or rotary screwdriver
def choose_tool_type():
    tool_type = input("Choose Hydraulic or Rotary screwdriver: ").strip().lower()
    return tool_type

# Function to choose tool subtype
def choose_tool_subtype(tool_type):
    if tool_type == 'hydraulic':
        subtype = input("Choose Pneumatic, Electric or Battery operated tool: ").strip().lower()
    elif tool_type == 'rotary':
        subtype = input("Choose Pneumatic, Electric or Battery operated tool (different from hydraulic): ").strip().lower()
    else:
        print("Invalid tool type selected.")
        return None
    return subtype

# Convert XLSX to CSV
def convert_xlsx_to_csv(xlsx_filename, csv_filename):
    data_xls = pd.read_excel(xlsx_filename, index_col=None)
    data_xls.to_csv(csv_filename, encoding='utf-8', index=False)

# Main function to run the program
def main():
    # Load data from CSV file
    
    # Convert the XLSX file to CSV
    convert_xlsx_to_csv('../ML_Data.xlsx', 'ML_Data.csv')
    data_table = load_data_from_csv('ML_Data.csv')
    
    size, quality = get_user_input()
    
    # Check if the combination exists in the data table
    if (size, quality) in data_table:
        print(f"Selected Size: {size}, Quality: {quality}")
        
        # Get Torque or Tensioner choice
        choice = choose_torque_or_tension()
        
        if choice == 'torque':
            value = data_table[(size, quality)]['Torque']
            print(f"The value corresponding to {choice} is: {value}")
            
            # Choose between hydraulic or rotary screwdriver
            tool_type = choose_tool_type()
            
            if tool_type in ['hydraulic', 'rotary']:
                subtype = choose_tool_subtype(tool_type)
                if subtype:
                    # Get the specific tool based on user selection
                    if tool_type == 'hydraulic':
                        tool_output = data_table[(size, quality)][f'Hydraulic {subtype.capitalize()} Tool']
                    else:
                        tool_output = data_table[(size, quality)][f'Rotary Screwdriver {subtype.capitalize()} Tool']
                    print(f"You have selected: {tool_output}")
                else:
                    print("No valid subtype selected.")
            else:
                print("Invalid tool type selected.")
        else:
            print("Invalid choice for Torque or Tensioner.")
    else:
        print("Invalid Size or Quality combination.")

# Run the program
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 118
#     116 # Run the program
#     117 if __name__ == "__main__":
# --> 118     main()
#
# Cell In[2], line 82, in main()
#      79 convert_xlsx_to_csv('../ML_Data.xlsx', 'ML_Data.csv')
#      80 data_table = load_data_from_csv('ML_Data.csv')
# ---> 82 size, quality = get_user_input()
#      84 # Check if the combination exists in the data table
#      85 if (size, quality) in data_table:
#
# Cell In[2], line 44, in get_user_input()
#      43 def get_user_input():
# ---> 44     size = int(input("Enter Size of bolt (e.g., 14): "))
#      45     quality = input("Choose Quality of bolt (e.g., 8.8, 10.9, 12.9): ")
#      46     return size, quality
#
# ValueError: invalid literal for int() with base 10: ''

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      -------------------------------------- 250.9/250.9 kB 7.5 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import csv
import pandas as pd

# Function to load data from a CSV file into a dictionary
def load_data_from_csv(filename):
    data_table = {}
    with open(filename, mode='r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            # Extract relevant data
            for quality in ['8.8', '10.9', '12.9']:
                if quality not in data_table:
                    data_table[quality] = {}
                size_bolt = int(row['Size Bolt [mm]'])
                # Store torque and tool names
                data_table[quality][size_bolt] = {
                    'Torque': row[f'{quality} Torque'],
                    'Tensioner': row[f'{quality} Tensioner'],
                    'Hydraulic Pneumatic Torque': row[f'{quality} Hydraulic Pneumatic Torque'],
                    'Hydraulic Electrical Torque': row[f'{quality} Hydraulic Electrical Torque'],
                    'Hydraulic Battery Torque': row[f'{quality} Hydraulic Battery Torque'],
                    'Rotary Screwdriver Pneumatic Torque': row[f'{quality} Rotatry Screwdriver Pneumatic Torque'],
                    'Rotary Screwdriver Electrical Torque': row[f'{quality} Rotatry Screwdriver Electrical Torque'],
                    'Rotary Screwdriver Battery Torque': row[f'{quality} Rotatry Screwdriver Battery Torque'],
                    'Pneumatic Tensioner': row[f'{quality} Pneumatic Tensioner'],
                    'Electrical Tensioner': row[f'{quality} Electrical Tensioner'],
                }
    return data_table

# Function to get user input for size and quality
def get_user_input():
    size = int(input("Enter Size of Bolt (e.g., 14): "))
    quality = input("Choose Quality of bolt (8.8, 10.9, 12.9): ")
    return size, quality

# Function to choose between Torque or Tensioner
def choose_torque_or_tension():
    choice = input("Choose (1) Torque or (2) Tensioner: ").strip()
    return choice

# Function to choose between hydraulic or rotary screwdriver
def choose_tool_type():
    tool_type = input("Choose (1) Hydraulic or (2) Rotary screwdriver: ").strip()
    return tool_type

# Function to choose tool subtype
def choose_tool_subtype(tool_type):
    if tool_type == '1':
        subtype = input("Choose (1) Pneumatic, (2) Electric, or (3) Battery operated tool: ").strip()
    elif tool_type == '2':
        subtype = input("Choose (1) Pneumatic, (2) Electric, or (3) Battery operated tool: ").strip()
    else:
        print("Invalid tool type selected.")
        return None
    return subtype
def convert_xlsx_to_csv(xlsx_file, csv_file):
    # Read the Excel file
    data_xls = pd.read_excel(xlsx_file, index_col=None)
    # Write to a CSV file
    data_xls.to_csv(csv_file, encoding='utf-8', index=False)

# Example usage
convert_xlsx_to_csv('../ML_Data.xlsx', 'ML_Data.csv')

# Main function to run the program
def main():
    # Load data from CSV file
    data_table = load_data_from_csv('ML_Data.csv')
    
    size, quality = get_user_input()
    
    # Check if the combination exists in the data table
    if quality in data_table and size in data_table[quality]:
        print(f"Selected Size: {size}, Quality: {quality}")
        
        # Get Torque or Tensioner choice
        choice = choose_torque_or_tension()
        
        if choice in ['1', '2']:
            value_key = 'Torque' if choice == '1' else 'Tensioner'
            value = data_table[quality][size][value_key]
            print(f"The value corresponding to {value_key} is: {value}")
            
            
            # Choose between hydraulic or rotary screwdriver
            tool_type = choose_tool_type()
            
            if tool_type in ['1', '2']:
                subtype = choose_tool_subtype(tool_type)
                if subtype:
                    # Determine which torque value to output based on user selection
                    if tool_type == '1':  # Hydraulic
                        if subtype == '1':
                            tool_name = data_table[quality][size]['Hydraulic Pneumatic Torque']
                        elif subtype == '2':
                            tool_name = data_table[quality][size]['Hydraulic Electrical Torque']
                        elif subtype == '3':
                            tool_name = data_table[quality][size]['Hydraulic Battery Torque']
                        else:
                            print("Invalid subtype selected.")
                            return
                    else:  # Rotary
                        if subtype == '1':
                            tool_name = data_table[quality][size]['Rotary Screwdriver Pneumatic Torque']
                        elif subtype == '2':
                            tool_name = data_table[quality][size]['Rotary Screwdriver Electrical Torque']
                        elif subtype == '3':
                            tool_name = data_table[quality][size]['Rotary Screwdriver Battery Torque']
                        else:
                            print("Invalid subtype selected.")
                            return
                    # Check for NaN or unavailable tools
                    if tool_name == '#N/A' or not tool_name:
                        print("No tool available for this configuration.")
                    else:
                        print(f"You have selected Tool: {tool_name}")
                else:
                    print("No valid subtype selected.")
            else:
                print("Invalid tool type selected.")
    elif value_key == 'Tensioner':  # Tensioner
                tensioner_type = input("Choose (1) Pneumatic Tensioner or (2) Electrical Tensioner: ").strip()
                if tensioner_type == '1':
                    tool_name = data_table[quality][size]['Pneumatic Tensioner']
                elif tensioner_type == '2':
                    tool_name = data_table[quality][size]['Electrical Tensioner']
                else:
                    print("Invalid tensioner type selected.")
                    return
                # Check for NaN or unavailable tools
                if tool_name == '#N/A' or not tool_name:
                    print("No tool available for this configuration.")
                else:
                    print(f"You have selected Tensioner Tool: {tool_name}")
        

# Run the program
if __name__ == "__main__":
    main()
# Out:
# Selected Size: 14, Quality: 8.8
# The value corresponding to Tensioner is: 58
# You have selected Tool: DE1-10
